# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'''
Your Code
'''
# Out:
# '\nYour Code\n'

# %%
r.text是以文字方式將內容取出。json.loads(r.text)則是能以json格式讀取內容

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11172215538","type":"CreateEvent","actor":{"id":3707102,"login":"Mazda--","display_login":"Mazda--","gravatar_id":"","url":"https://api.github.com/users/Mazda--","avatar_url":"https://avatars.githubusercontent.com/u/3707102?"},"repo":{"id":34234092,"name":"codeaurora-unofficial/platform-hardware-broadcom-libbt","url":"https://api.github.com/repos/codeaurora-unofficial/platform-hardware-broadcom-libbt"},"payload":{"ref":"LA.UM.6.7.c26","ref_type":"branch","master_branch":"LA.AF.1.1.c1","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-29T03:46:35Z","org":{"id":12023474,"login":"codeaurora-unofficial","gravatar_id":"","url":"https://api.github.com/orgs/codeaurora-unofficial","avatar_url":"https://avatars.githubusercontent.com/u/12023474?"}},{"id":"11172215539","type":"CreateEvent","actor":{"id":3707102,"login":"Mazda--","display_login":"Mazda--","gravatar_id":"","url":"https://api.github.com/users/Mazda--","avatar_url":"https://avatars.githubusercontent.com/u/3707102?"},"repo":{"id":34234229,"name":"codeaurora-unofficial/platform-hardware-libhardware","url":"https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware"},"payload":{"ref":"caf/LV.AU.0.0.2_rb1.2","ref_type":"branch","master_branch":"caf/LA.AF.1.1.c1","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-29T03:46:35Z","org":{"id":12023474,"login":"codeaurora-unofficial","gravatar_id":"","url":"https://api.github.com/orgs/codeaurora-unofficial","avatar_url":"https://avatars.githubusercontent.com/u/12023474?"}},{"id":"11172215537","type":"CreateEvent","actor":{"id":3707102,"login":"Mazda--","display_login":"Mazda--","gravatar_id":"","url":"https://api.github.com/users/Mazda--","avatar_url":"https://avatars.githubusercontent.com/u/3707102?"},"repo":{"id":34234521,"name":"codeaurora-unofficial/platform-hardware-qcom-display","url":"https://api.github.com/repos/codeaurora-unofficial/platform-hardware-qcom-display"},"payload":{"ref":"caf/LAW.BR.4.0.r1.2","ref_type":"branch","master_branch":"caf/LA.AF.1.1.c1","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-29T03:46:35Z","org":{"id":12023474,"login":"codeaurora-unofficial","gravatar_id":"","url":"https://api.github.com/orgs/codeaurora-unofficial","avatar_url":"https://avatars.githubusercontent.com/u/12023474?"}},{"id":"11172215534","type":"PushEvent","actor":{"id":1396050,"login":"Alfaj0r","display_login":"Alfaj0r","gravatar_id":"","url":"https://api.github.com/users/Alfaj0r","avatar_url":"https://avatars.githubusercontent.com/u/1396050?"},"repo":{"id":230697326,"name":"Alfaj0r/alfaj0rdotcom2019","url":"https://api.github.com/repos/Alfaj0r/alfaj0rdotcom2019"},"payload":{"push_id":4443206204,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"8ea69f658147beed160be4d9a4f9cb0b0dbc6c31","before":"ec1c19b4d54f8e08addf93984e5466b52877cd59","commits":[{"sha":"8ea69f658147beed160be4d9a4f9cb0b0dbc6c31","author":{"email":"nicoyogui@gmail.com","name":"Nico"},"message":"Delete 2019-04-09-basic-rules-for-walking-in-the-mountains.md","distinct":true,"url":"https://api.github.com/repos/Alfaj0r/alfaj0rdotcom2019/commits/8ea69f658147beed160be4d9a4f9cb0b0dbc6c31"}]},"public":true,"created_at":"2019-12-29T03:46:35Z"},{"id":"11172215533","type":"PushEvent","actor":{"id":59310048,"login":"zhucek","display_login":"zhucek","gravatar_id":"","url":"https://api.github.com/users/zhucek","avatar_url":"https://avatars.githubusercontent.com/u/59310048?"},"repo":{"id":230698556,"name":"zhucek/across","url":"https://api.github.com/repos/zhucek/across"},"payload":{"push_id":4443206206,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"434a6362eb345756fa7c1ab0f7eccb5647e6c48d","before":"aa7b8c33f163feb489197184f932362a87cc21e7","commits":[{"sha":"434a6362eb345756fa7c1ab0f7eccb5647e6c48d","author":{"email":"59310048+zhucek@users.noreply.github.com","name":"zhucek"},"message":"Update README.md","distinct":true,"url":"https://api.githu ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11172215538',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234092,
#    'name': 'codeaurora-unofficial/platform-hardware-broadcom-libbt',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-broadcom-libbt'},
#   'payload': {'ref': 'LA.UM.6.7.c26',
#    'ref_type': 'branch',
#    'master_branch': 'LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215539',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234229,
#    'name': 'codeaurora-unofficial/platform-hardware-libhardware',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware'},
#   'payload': {'ref': 'caf/LV.AU.0.0.2_rb1.2',
#    'ref_type': 'branch',
#    'master_branch': 'caf/LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215537',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234521,
#    'name': 'codeaurora-unofficial/platform-hardware-qcom-display',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-qcom-display'},
#   'payload': {'ref': 'caf/LAW.BR.4.0.r1.2',
#    'ref_type': 'branch',
#    'master_branch': 'caf/LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215534',
#   'type': 'PushEvent',
#   'actor': {'id': 1396050,
#    'login': 'Alfaj0r',
#    'display_login': 'Alfaj0r',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Alfaj0r',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1396050?'},
#   'repo': {'id': 230697326,
#    'name': 'Alfaj0r/alfaj0rdotcom2019',
#    'url': 'https://api.github.com/repos/Alfaj0r/alfaj0rdotcom2019'},
#   'payload': {'push_id': 4443206204,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8ea69f658147beed160be4d9a4f9cb0b0dbc6c31',
#    'before': 'ec1c19b4d54f8e08addf93984e5466b52877cd59',
#    'commits': [{'sha': '8ea69f658147beed160be4d9a4f9cb0b0dbc6c31',
#      'author': {'email': 'nicoyogui@gmail.com', 'name': 'Nico'},
#      'message': 'Delete 2019-04-09-basic-rules-for-walking-in-the-mountains.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Alfaj0r/alfaj0rdotcom2019/commits/8ea69f658147beed160be4d9a4f9cb0b0dbc6c31'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z'},
#  {'id': '11172215533',
#   'type': 'PushEvent',
#   'actor': {'id': 59310048,
#    'login': 'zhucek',
#    'display_login': 'zhucek',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhucek',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59310048?'},
#   'repo': {'id': 230698556,
#    'name': 'zhucek/across',
#    'url': 'https://api.github.com/repos/zhucek/across'},
#   'payload': {'push_id': 4443206206,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '434a6362eb345756fa7c1ab0f7eccb5647e6c48d',
#    'before': 'aa7b8c33f163feb489197184f932362a87cc21e7',
#    'commits': [{'sha': '434a6362eb345756fa7c1ab0f7eccb5647e6c48d',
#      'author': {'email': '59310048+zhucek@users.noreply.github.com',
#       'name': 'zhucek'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zhucek/across/commits/434a6362eb345756fa7c1ab0f7eccb5647e6c48d'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z'},
#  {'id': '11172215532',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234298,
#    'name': 'codeaurora-unofficial/platform-hardware-libhardware_legacy',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy'},
#   'payload': {'ref': 'caf/ks-aosp.lnx.2.0.r7-rel',
#    'ref_type': 'branch',
#    'master_branch': 'caf/LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215530',
#   'type': 'PushEvent',
#   'actor': {'id': 59002469,
#    'login': 'kportal-hub',
#    'display_login': 'kportal-hub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kportal-hub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59002469?'},
#   'repo': {'id': 230698997,
#    'name': 'kportal-hub/ntohidikplay-javascript-cube',
#    'url': 'https://api.github.com/repos/kportal-hub/ntohidikplay-javascript-cube'},
#   'payload': {'push_id': 4443206201,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1abb134d0b689cb6179e572ea3d163b2aab06e11',
#    'before': 'e8a4b127a397cb6489896bcc6597d619c156fe35',
#    'commits': [{'sha': '1abb134d0b689cb6179e572ea3d163b2aab06e11',
#      'author': {'email': 'unclecode@kplay.team', 'name': 'kportal-hub'},
#      'message': 'Update auth file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kportal-hub/ntohidikplay-javascript-cube/commits/1abb134d0b689cb6179e572ea3d163b2aab06e11'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z'},
#  {'id': '11172215531',
#   'type': 'CreateEvent',
#   'actor': {'id': 25905028,
#    'login': 'zhaoyiming',
#    'display_login': 'zhaoyiming',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhaoyiming',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25905028?'},
#   'repo': {'id': 230698499,
#    'name': 'zhaoyiming/MachineLearning_CourseraWork',
#    'url': 'https://api.github.com/repos/zhaoyiming/MachineLearning_CourseraWork'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': '吴恩达Coursera课后作业答案及pdf',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z'},
#  {'id': '11172215527',
#   'type': 'PushEvent',
#   'actor': {'id': 18365890,
#    'login': 'peter-evans',
#    'display_login': 'peter-evans',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/peter-evans',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18365890?'},
#   'repo': {'id': 99918615,
#    'name': 'peter-evans/nominatim-docker',
#    'url': 'https://api.github.com/repos/peter-evans/nominatim-docker'},
#   'payload': {'push_id': 4443206198,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9d6a41f2bf05dcd365164b2fe163d8885ef74ede',
#    'before': '197a042bc8d7dd8bcf01d11cd016447cfa864906',
#    'commits': [{'sha': '8cb10f1d1b7f14c615153c6b0d5b5e2489a5a9e4',
#      'author': {'email': 'peter-evans@users.noreply.github.com',
#       'name': 'Peter Evans'},
#      'message': 'Update Nominatim to version 3.4.1',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/peter-evans/nominatim-docker/commits/8cb10f1d1b7f14c615153c6b0d5b5e2489a5a9e4'},
#     {'sha': '9d6a41f2bf05dcd365164b2fe163d8885ef74ede',
#      'author': {'email': 'peter-evans@users.noreply.github.com',
#       'name': 'Peter Evans'},
#      'message': 'Merge pull request #19 from peter-evans/update-nominatim\n\nUpdate Nominatim to version 3.4.1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/peter-evans/nominatim-docker/commits/9d6a41f2bf05dcd365164b2fe163d8885ef74ede'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z'},
#  {'id': '11172215525',
#   'type': 'PushEvent',
#   'actor': {'id': 42130064,
#    'login': 'vldp2000',
#    'display_login': 'vldp2000',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vldp2000',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42130064?'},
#   'repo': {'id': 143675690,
#    'name': 'vldp2000/fcb1010',
#    'url': 'https://api.github.com/repos/vldp2000/fcb1010'},
#   'payload': {'push_id': 4443206197,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '30410a955834a4b2760a25d15ee48fb5519bba85',
#    'before': '8d24f80f02dae26584bd0c8d35ad5cb5fc0e262f',
#    'commits': [{'sha': '30410a955834a4b2760a25d15ee48fb5519bba85',
#      'author': {'email': '42130064+vldp2000@users.noreply.github.com',
#       'name': 'vldp2000'},
#      'message': 'add new user controls',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vldp2000/fcb1010/commits/30410a955834a4b2760a25d15ee48fb5519bba85'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z'},
#  {'id': '11172215526',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234092,
#    'name': 'codeaurora-unofficial/platform-hardware-broadcom-libbt',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-broadcom-libbt'},
#   'payload': {'ref': 'LA.UM.6.7.c25',
#    'ref_type': 'branch',
#    'master_branch': 'LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215524',
#   'type': 'IssuesEvent',
#   'actor': {'id': 38809560,
#    'login': 'btwise',
#    'display_login': 'btwise',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/btwise',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38809560?'},
#   'repo': {'id': 229246231,
#    'name': 'mackie100/OCClocalizations',
#    'url': 'https://api.github.com/repos/mackie100/OCClocalizations'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/mackie100/OCClocalizations/issues/3',
#     'repository_url': 'https://api.github.com/repos/mackie100/OCClocalizations',
#     'labels_url': 'https://api.github.com/repos/mackie100/OCClocalizations/issues/3/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/mackie100/OCClocalizations/issues/3/comments',
#     'events_url': 'https://api.github.com/repos/mackie100/OCClocalizations/issues/3/events',
#     'html_url': 'https://github.com/mackie100/OCClocalizations/issues/3',
#     'id': 543312590,
#     'node_id': 'MDU6SXNzdWU1NDMzMTI1OTA=',
#     'number': 3,
#     'title': "I don't understand",
#     'user': {'login': 'btwise',
#      'id': 38809560,
#      'node_id': 'MDQ6VXNlcjM4ODA5NTYw',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/38809560?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/btwise',
#      'html_url': 'https://github.com/btwise',
#      'followers_url': 'https://api.github.com/users/btwise/followers',
#      'following_url': 'https://api.github.com/users/btwise/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/btwise/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/btwise/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/btwise/subscriptions',
#      'organizations_url': 'https://api.github.com/users/btwise/orgs',
#      'repos_url': 'https://api.github.com/users/btwise/repos',
#      'events_url': 'https://api.github.com/users/btwise/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/btwise/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-29T03:46:34Z',
#     'updated_at': '2019-12-29T03:46:34Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'body': "All of the previous translations I tested in 1.10.2.0 seemed to work fine. I don't know why you made these changes?"}},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z'},
#  {'id': '11172215523',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234229,
#    'name': 'codeaurora-unofficial/platform-hardware-libhardware',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware'},
#   'payload': {'ref': 'caf/LV.AU.0.0.2_rb1.1',
#    'ref_type': 'branch',
#    'master_branch': 'caf/LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:35Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215515',
#   'type': 'PushEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234298,
#    'name': 'codeaurora-unofficial/platform-hardware-libhardware_legacy',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy'},
#   'payload': {'push_id': 4443206188,
#    'size': 45,
#    'distinct_size': 0,
#    'ref': 'refs/heads/caf/aosp-new/oreo-mr1-iot-release',
#    'head': '0f90ed1ffc9acf49194d76fe0947795198a56d2b',
#    'before': 'af03352f5503e6ace1b376f988a53857e021f2bf',
#    'commits': [{'sha': 'f7df1c20ce5afe3adde65a518865ed73483ed6b3',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'release-request-d4f45cf4-9d73-4828-baa4-f73aa4280cd0-for-git_pi-release-4241208 snap-temp-L10800000088711883\n\nChange-Id: I32f5f67db3618f47a83279de171e0b60b89b22fe',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/f7df1c20ce5afe3adde65a518865ed73483ed6b3'},
#     {'sha': 'cc7eaa949993847db9d2d7c54e793fe6d4b5bd2d',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'release-request-0b474cbb-ff20-424d-a570-a0a7b83a7705-for-git_pi-release-4262110 snap-temp-L42700000091449286\n\nChange-Id: I8d155e2fb9a949568a25fc910109118f75be0fa3',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/cc7eaa949993847db9d2d7c54e793fe6d4b5bd2d'},
#     {'sha': '3687b31920506d4cea4d919f9be87ea2d481ad01',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'Snap for 4373608 from a211035d88288786316d535a3d649d060be04f14 to pi-release\n\nChange-Id: I8eaed9d9b2770743cd4f5b99b881839b6c9de296',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/3687b31920506d4cea4d919f9be87ea2d481ad01'},
#     {'sha': '22ee4ab07c075692f39581e6d25a7f3559f17303',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'Snap for 4393550 from 67b598c76d080cb926f3078116441fc66ea1a5dc to pi-release\n\nChange-Id: I58adb7af29b8170cdd881bbb4a6bb194118144ee',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/22ee4ab07c075692f39581e6d25a7f3559f17303'},
#     {'sha': 'c2ff5b3ba2f2a569e28a4f7f7f8d941f18521383',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'Snap for 4502278 from c13dd636239233b2c9753c02a854df57d4090432 to pi-release\n\nChange-Id: I8c8efe3add6c96efd70c89c0d8eaa299d90ba697',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/c2ff5b3ba2f2a569e28a4f7f7f8d941f18521383'},
#     {'sha': '650e59721373d477921641c0d9e65a710995d7d2',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'Snap for 4507345 from a5d8dde1a978cb8236b9ce57cef11032be73afa0 to pi-release\n\nChange-Id: Icd1a675a9de2d02cde6cdb2f14155c76ea125c4f',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/650e59721373d477921641c0d9e65a710995d7d2'},
#     {'sha': 'd54673ab8d31dc72b0cab990773eb70ec530dcde',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'Snap for 4562879 from 3a106ee0e0660c5fc23256a0dbba0fe6eda68b3c to pi-release\n\nChange-Id: I48a5af3c3723a3e1c304bf9ae92d0dc3dd2ece5a',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/d54673ab8d31dc72b0cab990773eb70ec530dcde'},
#     {'sha': '64687219fb9b8d72a63d42e33f75e392034c4979',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'Snap for 4571561 from f0d31da98c3b0f5279622dd30453492a9ca83bef to pi-release\n\nChange-Id: I83d2f249fa90b68065418479d6c5ff8eb8881698',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/64687219fb9b8d72a63d42e33f75e392034c4979'},
#     {'sha': '4fe9b91691f99969f008119c7f545a06ccb9b2a7',
#      'author': {'email': 'android-build@google.com', 'name': 'gitbuildkicker'},
#      'message': 'merge in pi-release history after reset to master',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/4fe9b91691f99969f008119c7f545a06ccb9b2a7'},
#     {'sha': 'c7eea9aac84c74003ff5c3babbd08accbf4b0ad9',
#      'author': {'email': 'android-build@google.com', 'name': 'gitbuildkicker'},
#      'message': 'merge in pi-release history after reset to master',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/c7eea9aac84c74003ff5c3babbd08accbf4b0ad9'},
#     {'sha': '8ead30aec5af2f8722684ed876e47ccc0a934bdf',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'Snap for 4638586 from 9dfdd473dcd5a208bca9bc56a9a3c9220ef82d72 to pi-release\n\nChange-Id: I9ffedc5528e613f65312a674fc679145e88b735f',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/8ead30aec5af2f8722684ed876e47ccc0a934bdf'},
#     {'sha': '802820f6c672cbd28f64fc64f85e6675f59ac4c0',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'Snap for 4647811 from 8564c41780d8b1347b989dbc14abdd77947eaa48 to pi-release\n\nChange-Id: I416388ae2d941a28bfd350613130cbb1a4b952ae',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/802820f6c672cbd28f64fc64f85e6675f59ac4c0'},
#     {'sha': '3a032cff241f6d0692462353465a819ee3704423',
#      'author': {'email': 'android-build-team-robot@google.com',
#       'name': 'android-build-team Robot'},
#      'message': 'Snap for 4680594 from 8c64fe9b126d6e50ea12f0dd02b5d4716392e076 to pi-release\n\nChange-Id: I56daf73bb2d20dabb35212aab11ca06ad6afcd94',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/3a032cff241f6d0692462353465a819ee3704423'},
#     {'sha': 'ae3811a4eb3e396088f3fc768e939bf3488d3179',
#      'author': {'email': 'delphij@google.com', 'name': 'Xin Li'},
#      'message': 'Merge pi-dev-plus-aosp-without-vendor into stage-aosp-master\nam: d0dcc4afc1\n\nChange-Id: I0559e028bc42d133c9d50b4f2a7eab00a97cf230',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/ae3811a4eb3e396088f3fc768e939bf3488d3179'},
#     {'sha': 'a12551d1203e4411b96a253b92df3d75a4de412d',
#      'author': {'email': 'delphij@google.com', 'name': 'Xin Li'},
#      'message': 'Merge "Merge Android Pie into master"\nam: af03352f55\n\nChange-Id: I36c1fc8dc96058e174dbf16b243f7716e8979987',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/a12551d1203e4411b96a253b92df3d75a4de412d'},
#     {'sha': 'd0c11842c98d6a7fcde7423b30e19995746e2e6d',
#      'author': {'email': 'delphij@google.com', 'name': 'Xin Li'},
#      'message': 'Merge "Merge Android Pie into master" am: af03352f55\nam: a12551d120\n\nChange-Id: I82efb3d1d9466fcafa81e287f8cd0329b08c06f8',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/d0c11842c98d6a7fcde7423b30e19995746e2e6d'},
#     {'sha': 'e0a9c90bf5ab1ba58b7435a602713227fb052e4a',
#      'author': {'email': 'trong@google.com', 'name': 'Tri Vo'},
#      'message': 'libpower: acquire wake locks from SystemSuspend service.\n\nThis change routes libpower and libhardware_legacy to SystemSuspend service for\nwake locks instead of /sys/power/wake_[un]lock.\n\nBug: 78888165\nBug: 115946999\nTest: /sys/kernel/debug/suspend_stats shows that device suspends if left alone\nChange-Id: Id4d392e13d06be6d86e3112dedeb6a57bb24c06f',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/e0a9c90bf5ab1ba58b7435a602713227fb052e4a'},
#     {'sha': 'aa8f6d2a2dcface3e5a51118a84152d98a6590f7',
#      'author': {'email': 'trong@google.com', 'name': 'Tri Vo'},
#      'message': 'Merge "libpower: acquire wake locks from SystemSuspend service."',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/aa8f6d2a2dcface3e5a51118a84152d98a6590f7'},
#     {'sha': 'f65f240c32d11b7b8a23eb486b40520f08e2e6d5',
#      'author': {'email': 'trong@google.com', 'name': 'Tri Vo'},
#      'message': 'Merge "libpower: acquire wake locks from SystemSuspend service."\nam: aa8f6d2a2d\n\nChange-Id: Icba174bcfa41904baaa977efa5e937ea57dd0257',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/f65f240c32d11b7b8a23eb486b40520f08e2e6d5'},
#     {'sha': '8eb59a0050da42162b78444538e271989fed23f6',
#      'author': {'email': 'trong@google.com', 'name': 'Tri Vo'},
#      'message': 'Simplify libpower\n\nChanged:\n- simplified getting system suspend service\n- added isOk() check when releasing a wake lock\n\nBug: 117575503\nTest: presubmit\nChange-Id: I78f1f50a7670e7df88e59999c35f99a6df06e8ef',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy/commits/8eb59a0050da42162b78444538e271989fed23f6'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215521',
#   'type': 'PushEvent',
#   'actor': {'id': 47855474,
#    'login': 'zeit-github-tester[bot]',
#    'display_login': 'zeit-github-tester',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zeit-github-tester[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47855474?'},
#   'repo': {'id': 171865482,
#    'name': 'zeit-github-test/github-e2e-tests-production',
#    'url': 'https://api.github.com/repos/zeit-github-test/github-e2e-tests-production'},
#   'payload': {'push_id': 4443206195,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/some-other-branch',
#    'head': 'c2fa97d9cd905967b58733053aa904b2a29a6ac5',
#    'before': '18a76b4636a26c437c53ab5939cf156e69c11f15',
#    'commits': [{'sha': 'c2fa97d9cd905967b58733053aa904b2a29a6ac5',
#      'author': {'email': '47855474+zeit-github-tester[bot]@users.noreply.github.com',
#       'name': 'zeit-github-tester[bot]'},
#      'message': 'Update: index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zeit-github-test/github-e2e-tests-production/commits/c2fa97d9cd905967b58733053aa904b2a29a6ac5'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z',
#   'org': {'id': 42106398,
#    'login': 'zeit-github-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/zeit-github-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42106398?'}},
#  {'id': '11172215518',
#   'type': 'PushEvent',
#   'actor': {'id': 36267396,
#    'login': 'Ricardoyecla',
#    'display_login': 'Ricardoyecla',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ricardoyecla',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36267396?'},
#   'repo': {'id': 222120244,
#    'name': 'Ricardoyecla/mi_daw',
#    'url': 'https://api.github.com/repos/Ricardoyecla/mi_daw'},
#   'payload': {'push_id': 4443206191,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2c263bd6ea318f9a13a83f47e3435b8081dc98f8',
#    'before': 'cfe4cfc0eb2952ff47153ad08615e0e755e8cc0a',
#    'commits': [{'sha': '2c263bd6ea318f9a13a83f47e3435b8081dc98f8',
#      'author': {'email': 'ricardoyecla@gmail.com', 'name': 'RicardoYecla'},
#      'message': 'Inocentes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ricardoyecla/mi_daw/commits/2c263bd6ea318f9a13a83f47e3435b8081dc98f8'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z'},
#  {'id': '11172215520',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234521,
#    'name': 'codeaurora-unofficial/platform-hardware-qcom-display',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-qcom-display'},
#   'payload': {'ref': 'caf/LV.HB.1.1.5_rb1.14',
#    'ref_type': 'branch',
#    'master_branch': 'caf/LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215514',
#   'type': 'PushEvent',
#   'actor': {'id': 7677092,
#    'login': 'jetzlstorfer',
#    'display_login': 'jetzlstorfer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jetzlstorfer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7677092?'},
#   'repo': {'id': 229062099,
#    'name': 'keptn-public-demo/sockshop',
#    'url': 'https://api.github.com/repos/keptn-public-demo/sockshop'},
#   'payload': {'push_id': 4443206192,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/staging',
#    'head': '414ecb37bba52e4f9b998e6849171c5fca537161',
#    'before': '2198701c96aadfb3cc4b9e98322c16e7c87baf30',
#    'commits': [{'sha': '414ecb37bba52e4f9b998e6849171c5fca537161',
#      'author': {'email': 'keptn@keptn.com', 'name': 'keptn'},
#      'message': 'Added resources',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/keptn-public-demo/sockshop/commits/414ecb37bba52e4f9b998e6849171c5fca537161'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z',
#   'org': {'id': 59056118,
#    'login': 'keptn-public-demo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/keptn-public-demo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59056118?'}},
#  {'id': '11172215512',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234092,
#    'name': 'codeaurora-unofficial/platform-hardware-broadcom-libbt',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-broadcom-libbt'},
#   'payload': {'ref': 'aosp-new/simpleperf-release',
#    'ref_type': 'branch',
#    'master_branch': 'LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215511',
#   'type': 'PushEvent',
#   'actor': {'id': 54234214,
#    'login': 'Dream-LC',
#    'display_login': 'Dream-LC',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dream-LC',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54234214?'},
#   'repo': {'id': 212728439,
#    'name': 'Dream-LC/gitalk',
#    'url': 'https://api.github.com/repos/Dream-LC/gitalk'},
#   'payload': {'push_id': 4443206185,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '430be2306abe9d5f18760529bc922ce9c29289f0',
#    'before': 'c332671d3d0347e329c55357351e3b74d3879319',
#    'commits': [{'sha': '430be2306abe9d5f18760529bc922ce9c29289f0',
#      'author': {'email': '54234214+Dream-LC@users.noreply.github.com',
#       'name': 'Dream'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Dream-LC/gitalk/commits/430be2306abe9d5f18760529bc922ce9c29289f0'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z'},
#  {'id': '11172215510',
#   'type': 'ForkEvent',
#   'actor': {'id': 157957,
#    'login': 'Gassa',
#    'display_login': 'Gassa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Gassa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/157957?'},
#   'repo': {'id': 159658646,
#    'name': 'kaiwaehner/python-jupyter-apache-kafka-ksql-tensorflow-keras',
#    'url': 'https://api.github.com/repos/kaiwaehner/python-jupyter-apache-kafka-ksql-tensorflow-keras'},
#   'payload': {'forkee': {'id': 230699043,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMzA2OTkwNDM=',
#     'name': 'python-jupyter-apache-kafka-ksql-tensorflow-keras',
#     'full_name': 'Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras',
#     'private': False,
#     'owner': {'login': 'Gassa',
#      'id': 157957,
#      'node_id': 'MDQ6VXNlcjE1Nzk1Nw==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/157957?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Gassa',
#      'html_url': 'https://github.com/Gassa',
#      'followers_url': 'https://api.github.com/users/Gassa/followers',
#      'following_url': 'https://api.github.com/users/Gassa/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Gassa/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Gassa/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Gassa/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Gassa/orgs',
#      'repos_url': 'https://api.github.com/users/Gassa/repos',
#      'events_url': 'https://api.github.com/users/Gassa/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Gassa/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras',
#     'description': 'Making Machine Learning Simple and Scalable with Python, Jupyter Notebook, TensorFlow, Keras, Apache Kafka and KSQL',
#     'fork': True,
#     'url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras',
#     'forks_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/forks',
#     'keys_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/teams',
#     'hooks_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/hooks',
#     'issue_events_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/events',
#     'assignees_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/tags',
#     'blobs_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/languages',
#     'stargazers_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/stargazers',
#     'contributors_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/contributors',
#     'subscribers_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/subscribers',
#     'subscription_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/subscription',
#     'commits_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/merges',
#     'archive_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/downloads',
#     'issues_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras/deployments',
#     'created_at': '2019-12-29T03:46:33Z',
#     'updated_at': '2019-12-24T00:13:33Z',
#     'pushed_at': '2019-01-27T17:24:14Z',
#     'git_url': 'git://github.com/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras.git',
#     'ssh_url': 'git@github.com:Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras.git',
#     'clone_url': 'https://github.com/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras.git',
#     'svn_url': 'https://github.com/Gassa/python-jupyter-apache-kafka-ksql-tensorflow-keras',
#     'homepage': None,
#     'size': 69112,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z'},
#  {'id': '11172215509',
#   'type': 'PushEvent',
#   'actor': {'id': 4167084,
#    'login': 'novrain',
#    'display_login': 'novrain',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/novrain',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4167084?'},
#   'repo': {'id': 216488594,
#    'name': 'iota-cn/vue-iota-avatar',
#    'url': 'https://api.github.com/repos/iota-cn/vue-iota-avatar'},
#   'payload': {'push_id': 4443206182,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bafe3d10087160e157aebf678b8eba9c60fa8889',
#    'before': 'e0e2ba0fbc55f8b34832cca65350d6144cd8b93f',
#    'commits': [{'sha': 'bafe3d10087160e157aebf678b8eba9c60fa8889',
#      'author': {'email': 'novrainn@gmail.com', 'name': 'novrain'},
#      'message': ':hammer: add prepublish, change build to lib',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/iota-cn/vue-iota-avatar/commits/bafe3d10087160e157aebf678b8eba9c60fa8889'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z',
#   'org': {'id': 56809886,
#    'login': 'iota-cn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/iota-cn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56809886?'}},
#  {'id': '11172215508',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234521,
#    'name': 'codeaurora-unofficial/platform-hardware-qcom-display',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-qcom-display'},
#   'payload': {'ref': 'caf/LV.HB.1.1.5_rb1.12',
#    'ref_type': 'branch',
#    'master_branch': 'caf/LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215506',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 18365890,
#    'login': 'peter-evans',
#    'display_login': 'peter-evans',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/peter-evans',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18365890?'},
#   'repo': {'id': 99918615,
#    'name': 'peter-evans/nominatim-docker',
#    'url': 'https://api.github.com/repos/peter-evans/nominatim-docker'},
#   'payload': {'action': 'closed',
#    'number': 19,
#    'pull_request': {'url': 'https://api.github.com/repos/peter-evans/nominatim-docker/pulls/19',
#     'id': 357606021,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU3NjA2MDIx',
#     'html_url': 'https://github.com/peter-evans/nominatim-docker/pull/19',
#     'diff_url': 'https://github.com/peter-evans/nominatim-docker/pull/19.diff',
#     'patch_url': 'https://github.com/peter-evans/nominatim-docker/pull/19.patch',
#     'issue_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/issues/19',
#     'number': 19,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Update Nominatim to version 3.4.1',
#     'user': {'login': 'peter-evans',
#      'id': 18365890,
#      'node_id': 'MDQ6VXNlcjE4MzY1ODkw',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/18365890?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/peter-evans',
#      'html_url': 'https://github.com/peter-evans',
#      'followers_url': 'https://api.github.com/users/peter-evans/followers',
#      'following_url': 'https://api.github.com/users/peter-evans/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/peter-evans/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/peter-evans/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/peter-evans/subscriptions',
#      'organizations_url': 'https://api.github.com/users/peter-evans/orgs',
#      'repos_url': 'https://api.github.com/users/peter-evans/repos',
#      'events_url': 'https://api.github.com/users/peter-evans/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/peter-evans/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-12-29T03:37:59Z',
#     'updated_at': '2019-12-29T03:46:33Z',
#     'closed_at': '2019-12-29T03:46:33Z',
#     'merged_at': '2019-12-29T03:46:33Z',
#     'merge_commit_sha': '9d6a41f2bf05dcd365164b2fe163d8885ef74ede',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/pulls/19/commits',
#     'review_comments_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/pulls/19/comments',
#     'review_comment_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/issues/19/comments',
#     'statuses_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/statuses/8cb10f1d1b7f14c615153c6b0d5b5e2489a5a9e4',
#     'head': {'label': 'peter-evans:update-nominatim',
#      'ref': 'update-nominatim',
#      'sha': '8cb10f1d1b7f14c615153c6b0d5b5e2489a5a9e4',
#      'user': {'login': 'peter-evans',
#       'id': 18365890,
#       'node_id': 'MDQ6VXNlcjE4MzY1ODkw',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/18365890?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/peter-evans',
#       'html_url': 'https://github.com/peter-evans',
#       'followers_url': 'https://api.github.com/users/peter-evans/followers',
#       'following_url': 'https://api.github.com/users/peter-evans/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/peter-evans/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/peter-evans/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/peter-evans/subscriptions',
#       'organizations_url': 'https://api.github.com/users/peter-evans/orgs',
#       'repos_url': 'https://api.github.com/users/peter-evans/repos',
#       'events_url': 'https://api.github.com/users/peter-evans/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/peter-evans/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 99918615,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk5OTkxODYxNQ==',
#       'name': 'nominatim-docker',
#       'full_name': 'peter-evans/nominatim-docker',
#       'private': False,
#       'owner': {'login': 'peter-evans',
#        'id': 18365890,
#        'node_id': 'MDQ6VXNlcjE4MzY1ODkw',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/18365890?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/peter-evans',
#        'html_url': 'https://github.com/peter-evans',
#        'followers_url': 'https://api.github.com/users/peter-evans/followers',
#        'following_url': 'https://api.github.com/users/peter-evans/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/peter-evans/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/peter-evans/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/peter-evans/subscriptions',
#        'organizations_url': 'https://api.github.com/users/peter-evans/orgs',
#        'repos_url': 'https://api.github.com/users/peter-evans/repos',
#        'events_url': 'https://api.github.com/users/peter-evans/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/peter-evans/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/peter-evans/nominatim-docker',
#       'description': 'Docker image for Nominatim',
#       'fork': False,
#       'url': 'https://api.github.com/repos/peter-evans/nominatim-docker',
#       'forks_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/forks',
#       'keys_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/teams',
#       'hooks_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/hooks',
#       'issue_events_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/events',
#       'assignees_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/tags',
#       'blobs_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/git/tags{/sha}',
# ...
#       'created_at': '2017-08-10T12:05:00Z',
#       'updated_at': '2019-11-10T13:19:40Z',
#       'pushed_at': '2019-12-29T03:46:33Z',
#       'git_url': 'git://github.com/peter-evans/nominatim-docker.git',
#       'ssh_url': 'git@github.com:peter-evans/nominatim-docker.git',
#       'clone_url': 'https://github.com/peter-evans/nominatim-docker.git',
#       'svn_url': 'https://github.com/peter-evans/nominatim-docker',
#       'homepage': 'https://hub.docker.com/r/peterevans/nominatim/',
#       'size': 41,
#       'stargazers_count': 10,
#       'watchers_count': 10,
#       'language': 'Dockerfile',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 7,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 7,
#       'open_issues': 2,
#       'watchers': 10,
#       'default_branch': 'master'}},
#     'base': {'label': 'peter-evans:master',
#      'ref': 'master',
#      'sha': '197a042bc8d7dd8bcf01d11cd016447cfa864906',
#      'user': {'login': 'peter-evans',
#       'id': 18365890,
#       'node_id': 'MDQ6VXNlcjE4MzY1ODkw',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/18365890?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/peter-evans',
#       'html_url': 'https://github.com/peter-evans',
#       'followers_url': 'https://api.github.com/users/peter-evans/followers',
#       'following_url': 'https://api.github.com/users/peter-evans/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/peter-evans/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/peter-evans/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/peter-evans/subscriptions',
#       'organizations_url': 'https://api.github.com/users/peter-evans/orgs',
#       'repos_url': 'https://api.github.com/users/peter-evans/repos',
#       'events_url': 'https://api.github.com/users/peter-evans/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/peter-evans/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 99918615,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk5OTkxODYxNQ==',
#       'name': 'nominatim-docker',
#       'full_name': 'peter-evans/nominatim-docker',
#       'private': False,
#       'owner': {'login': 'peter-evans',
#        'id': 18365890,
#        'node_id': 'MDQ6VXNlcjE4MzY1ODkw',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/18365890?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/peter-evans',
#        'html_url': 'https://github.com/peter-evans',
#        'followers_url': 'https://api.github.com/users/peter-evans/followers',
#        'following_url': 'https://api.github.com/users/peter-evans/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/peter-evans/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/peter-evans/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/peter-evans/subscriptions',
#        'organizations_url': 'https://api.github.com/users/peter-evans/orgs',
#        'repos_url': 'https://api.github.com/users/peter-evans/repos',
#        'events_url': 'https://api.github.com/users/peter-evans/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/peter-evans/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/peter-evans/nominatim-docker',
#       'description': 'Docker image for Nominatim',
#       'fork': False,
#       'url': 'https://api.github.com/repos/peter-evans/nominatim-docker',
#       'forks_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/forks',
#       'keys_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/teams',
#       'hooks_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/hooks',
#       'issue_events_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/events',
#       'assignees_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/tags',
#       'blobs_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/languages',
#       'stargazers_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/stargazers',
#       'contributors_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/contributors',
#       'subscribers_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/subscribers',
#       'subscription_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/subscription',
#       'commits_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/merges',
#       'archive_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/downloads',
#       'issues_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/peter-evans/nominatim-docker/deployments',
#       'created_at': '2017-08-10T12:05:00Z',
#       'updated_at': '2019-11-10T13:19:40Z',
#       'pushed_at': '2019-12-29T03:46:33Z',
#       'git_url': 'git://github.com/peter-evans/nominatim-docker.git',
#       'ssh_url': 'git@github.com:peter-evans/nominatim-docker.git',
#       'clone_url': 'https://github.com/peter-evans/nominatim-docker.git',
#       'svn_url': 'https://github.com/peter-evans/nominatim-docker',
#       'homepage': 'https://hub.docker.com/r/peterevans/nominatim/',
#       'size': 41,
#       'stargazers_count': 10,
#       'watchers_count': 10,
#       'language': 'Dockerfile',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 7,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 7,
#       'open_issues': 2,
#       'watchers': 10,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/peter-evans/nominatim-docker/pulls/19'},
#      'html': {'href': 'https://github.com/peter-evans/nominatim-docker/pull/19'},
#      'issue': {'href': 'https://api.github.com/repos/peter-evans/nominatim-docker/issues/19'},
#      'comments': {'href': 'https://api.github.com/repos/peter-evans/nominatim-docker/issues/19/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/peter-evans/nominatim-docker/pulls/19/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/peter-evans/nominatim-docker/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/peter-evans/nominatim-docker/pulls/19/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/peter-evans/nominatim-docker/statuses/8cb10f1d1b7f14c615153c6b0d5b5e2489a5a9e4'}},
#     'author_association': 'OWNER',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'peter-evans',
#      'id': 18365890,
#      'node_id': 'MDQ6VXNlcjE4MzY1ODkw',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/18365890?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/peter-evans',
#      'html_url': 'https://github.com/peter-evans',
#      'followers_url': 'https://api.github.com/users/peter-evans/followers',
#      'following_url': 'https://api.github.com/users/peter-evans/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/peter-evans/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/peter-evans/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/peter-evans/subscriptions',
#      'organizations_url': 'https://api.github.com/users/peter-evans/orgs',
#      'repos_url': 'https://api.github.com/users/peter-evans/repos',
#      'events_url': 'https://api.github.com/users/peter-evans/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/peter-evans/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 2,
#     'deletions': 2,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z'},
#  {'id': '11172215505',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234229,
#    'name': 'codeaurora-unofficial/platform-hardware-libhardware',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware'},
#   'payload': {'ref': 'caf/LV.AU.0.0.1_rb1.9',
#    'ref_type': 'branch',
#    'master_branch': 'caf/LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215504',
#   'type': 'DeleteEvent',
#   'actor': {'id': 1473059,
#    'login': 'hihain',
#    'display_login': 'hihain',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hihain',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1473059?'},
#   'repo': {'id': 230682495,
#    'name': 'hihain/WindowsTemplateStudio',
#    'url': 'https://api.github.com/repos/hihain/WindowsTemplateStudio'},
#   'payload': {'ref': 'Loc20181018', 'ref_type': 'tag', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z'},
#  {'id': '11172215502',
#   'type': 'CreateEvent',
#   'actor': {'id': 59325685,
#    'login': 'ignate-ig',
#    'display_login': 'ignate-ig',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ignate-ig',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59325685?'},
#   'repo': {'id': 230699042,
#    'name': 'ignate-ig/ignate',
#    'url': 'https://api.github.com/repos/ignate-ig/ignate'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z'},
#  {'id': '11172215500',
#   'type': 'PushEvent',
#   'actor': {'id': 48333010,
#    'login': 'Shinelior',
#    'display_login': 'Shinelior',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Shinelior',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48333010?'},
#   'repo': {'id': 230166156,
#    'name': 'Shinelior/programming-univbasics-nds-nds-to-insight-with-flexibility-lab-nyc-web-010620',
#    'url': 'https://api.github.com/repos/Shinelior/programming-univbasics-nds-nds-to-insight-with-flexibility-lab-nyc-web-010620'},
#   'payload': {'push_id': 4443206178,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '692e1d7f4b07d911a4ae4b597827fd52b9d72fbb',
#    'before': 'b87006336e1d58476d25a1f4ef0de9978ad29236',
#    'commits': [{'sha': '692e1d7f4b07d911a4ae4b597827fd52b9d72fbb',
#      'author': {'email': 'shinelior@gmail.com', 'name': 'lior Shine'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Shinelior/programming-univbasics-nds-nds-to-insight-with-flexibility-lab-nyc-web-010620/commits/692e1d7f4b07d911a4ae4b597827fd52b9d72fbb'}]},
#   'public': True,
#   'created_at': '2019-12-29T03:46:34Z'},
#  {'id': '11172215498',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234298,
#    'name': 'codeaurora-unofficial/platform-hardware-libhardware_legacy',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-libhardware_legacy'},
#   'payload': {'ref': 'caf/LA.AU.0.1.0.r2',
#    'ref_type': 'branch',
#    'master_branch': 'caf/LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:33Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}},
#  {'id': '11172215497',
#   'type': 'CreateEvent',
#   'actor': {'id': 3707102,
#    'login': 'Mazda--',
#    'display_login': 'Mazda--',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mazda--',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3707102?'},
#   'repo': {'id': 34234521,
#    'name': 'codeaurora-unofficial/platform-hardware-qcom-display',
#    'url': 'https://api.github.com/repos/codeaurora-unofficial/platform-hardware-qcom-display'},
#   'payload': {'ref': 'caf/LV.HB.1.1.5_rb1.11',
#    'ref_type': 'branch',
#    'master_branch': 'caf/LA.AF.1.1.c1',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-29T03:46:33Z',
#   'org': {'id': 12023474,
#    'login': 'codeaurora-unofficial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codeaurora-unofficial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12023474?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
#     'name': {'first': 'David', 'last': 'Gippner'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475ca8a99c3f00140fe4d0',
#    'text': 'Loyal, playful, and alert, Manx are considered to be more "doglike" than other cats.',
# ...
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1290f1c57001592f12a',
#    'type': 'cat',
#    'text': 'Bobtail cats owe their shortened tails to a natural genetic mutation that has appeared in cats across time and in various regions of the world. The American Bobtail can be traced back to Yodi, a cat with the mutation that was found in Arizona in the 1960s. Yodi passed the genetic quirk on to his kittens, thus creating a new breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df895e6b803950015c7b378',
#    'type': 'cat',
#    'text': 'แมวมี 9 ชีวิตนะ :D.',
#    'user': {'_id': '5df86094c555480015a3e3ae',
#     'name': {'first': 'Thanadols', 'last': 'Supho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df895ffb803950015c7b379',
#    'type': 'cat',
#    'text': 'Aaa.',
#    'user': {'_id': '5df86094c555480015a3e3ae',
#     'name': {'first': 'Thanadols', 'last': 'Supho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df8a7cbb803950015c7b37e',
#    'type': 'cat',
#    'text': 'Cats survive is you throw them out of any window.',
#    'user': {'_id': '5df89892b803950015c7b37a',
#     'name': {'first': 'Wolfgang', 'last': 'Gruel'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
