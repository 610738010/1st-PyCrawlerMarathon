# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %%
'''
Your Code
'''

# %%
xmltodict可以直接讀取目標資料，不用整個開file；而File I/O則是當如果不知道文件裡有什麼結構，可以用這種方式打開全文件
# Out:
# Unable to create process using 'C:\Users\Andrew Yeh\Anaconda3\python.exe "C:\Users\Andrew Yeh\Anaconda3\Scripts\pip-script.py" install xmltodict'

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
# 1. 請問高雄市有多少地區有溫度資料？
! pip install xmltodict
import xmltodict

with open('E./data/64_72hr_CH.xml', encoding='UTF-8') as fd:
    doc = xmltodict.parse(fd.read())

area_tempers = doc['cwbopendata']['dataset']['locations']['location']

print('高雄有', len(area_tempers), '個地區有溫度資料')
# Out:
# Requirement already satisfied: xmltodict in d:\anaconda\lib\site-packages (0.12.0)
# 高雄有 38 個地區有溫度資料

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度

for area_temper in area_tempers:
    print(area_temper['locationName'])
    print(area_temper['weatherElement'][0]['time'][0]['dataTime'])
    print(area_temper['weatherElement'][0]['time'][0]['elementValue']['value'], area_temper['weatherElement'][0]['time'][0]['elementValue']['measures'])
# Out:
# 鹽埕區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 鼓山區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 左營區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 楠梓區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 三民區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 新興區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 前金區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 苓雅區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 前鎮區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 旗津區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 小港區
# 2019-12-28T18:00:00+08:00
# 23 攝氏度
# 鳳山區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 林園區
# 2019-12-28T18:00:00+08:00
# 23 攝氏度
# 大寮區
# 2019-12-28T18:00:00+08:00
# 23 攝氏度
# 大樹區
# 2019-12-28T18:00:00+08:00
# 23 攝氏度
# 大社區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 仁武區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 鳥松區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 岡山區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 橋頭區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 燕巢區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 田寮區
# 2019-12-28T18:00:00+08:00
# 21 攝氏度
# 阿蓮區
# 2019-12-28T18:00:00+08:00
# 21 攝氏度
# 路竹區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 湖內區
# 2019-12-28T18:00:00+08:00
# 21 攝氏度
# 茄萣區
# 2019-12-28T18:00:00+08:00
# 20 攝氏度
# 永安區
# 2019-12-28T18:00:00+08:00
# 21 攝氏度
# 彌陀區
# 2019-12-28T18:00:00+08:00
# 21 攝氏度
# 梓官區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 旗山區
# 2019-12-28T18:00:00+08:00
# 21 攝氏度
# 美濃區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 六龜區
# 2019-12-28T18:00:00+08:00
# 20 攝氏度
# 甲仙區
# 2019-12-28T18:00:00+08:00
# 18 攝氏度
# 杉林區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 內門區
# 2019-12-28T18:00:00+08:00
# 21 攝氏度
# 茂林區
# 2019-12-28T18:00:00+08:00
# 21 攝氏度
# 桃源區
# 2019-12-28T18:00:00+08:00
# 18 攝氏度
# 那瑪夏區
# 2019-12-28T18:00:00+08:00
# 17 攝氏度

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

area = area_tempers[0]
print(area['locationName'])

for area1 in area['weatherElement'][0]['time']:
    print(area1['dataTime'])
    print(area1['elementValue']['value'], area1['elementValue']['measures'])
# Out:
# 鹽埕區
# 2019-12-28T18:00:00+08:00
# 22 攝氏度
# 2019-12-28T21:00:00+08:00
# 21 攝氏度
# 2019-12-29T00:00:00+08:00
# 20 攝氏度
# 2019-12-29T03:00:00+08:00
# 19 攝氏度
# 2019-12-29T06:00:00+08:00
# 19 攝氏度
# 2019-12-29T09:00:00+08:00
# 20 攝氏度
# 2019-12-29T12:00:00+08:00
# 23 攝氏度
# 2019-12-29T15:00:00+08:00
# 24 攝氏度
# 2019-12-29T18:00:00+08:00
# 22 攝氏度
# 2019-12-29T21:00:00+08:00
# 21 攝氏度
# 2019-12-30T00:00:00+08:00
# 20 攝氏度
# 2019-12-30T03:00:00+08:00
# 20 攝氏度
# 2019-12-30T06:00:00+08:00
# 19 攝氏度
# 2019-12-30T09:00:00+08:00
# 21 攝氏度
# 2019-12-30T12:00:00+08:00
# 26 攝氏度
# 2019-12-30T15:00:00+08:00
# 26 攝氏度
# 2019-12-30T18:00:00+08:00
# 24 攝氏度
# 2019-12-30T21:00:00+08:00
# 23 攝氏度
# 2019-12-31T00:00:00+08:00
# 21 攝氏度
# 2019-12-31T03:00:00+08:00
# 21 攝氏度
# 2019-12-31T06:00:00+08:00
# 20 攝氏度
# 2019-12-31T09:00:00+08:00
# 21 攝氏度
# 2019-12-31T12:00:00+08:00
# 24 攝氏度
# 2019-12-31T15:00:00+08:00
# 25 攝氏度
